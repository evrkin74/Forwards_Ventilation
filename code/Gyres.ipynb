# %%
#subset by longitude to look for local effects
import os
import sys
import matplotlib
import matplotlib.pyplot as plt
import dask.array as da
import dask 
import dask.dataframe as dd
import xarray as xr
from xnemogcm import open_domain_cfg, get_metrics
import xgcm
import cartopy.crs as ccrs
import cmocean
import numpy as np
from matplotlib.colors import Normalize

from scipy.stats import linregress
import datetime
import pandas as pd
import plots_spatial as pltspat
# Add SouthernDemons library to PATH
sys.path.append(os.path.abspath("../lib/"))
from teos_ten import teos_sigma0
import datesandtime

# Subdomain information (As inputted into TRACMASS, note non-pythonic indexing)
imindom = 1
imaxdom = 1440
jmindom = 1
jmaxdom = 400
kmindom = 1
kmaxdom = 75

# Location of the TRACMASS run
data_dir = os.path.abspath("/gws/nopw/j04/bas_pog/astyles/ORCA025_fwd/")

# Location of the OUTPUT directory created when running SouthernDemons executable
out_dir = os.path.abspath(data_dir + "/OUTPUT.ORCA025_fwd_extra/")
ndense_path = os.path.abspath("/gws/nopw/j04/bas_pog/astyles/SouthernDemons/neutraldensity/output/ORCA025_Dec1982/*.nc" )
# Location of masks and grid information for the model
grid_path = os.path.abspath("/gws/nopw/j04/bas_pog/astyles/ORCA025_fwd/topo" )
grid_files = ['mask.nc','mesh_hgr.nc','mesh_zgr.nc']

cal_months = ["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]
col = ['red','green','yellow']
# Use dask to load the tabulated data lazily 
#df_ini = dd.read_parquet(out_dir + f"/df_ini.combined.parquet")
#df_out = dd.read_parquet(out_dir + f"/df_out.combined.parquet")
data_dir = os.path.abspath("/gws/nopw/j04/bas_pog/evrkin74/Forwards_Ventilation")
df_vent = dd.read_parquet(data_dir + f"/df_vent.parquet")
ds_domain = open_domain_cfg( datadir=grid_path, files = grid_files )

# %%
len(df_vent['density_o'])
# Out:
# 54157552

# %%
def plot_o(ds_domain, vol_xy, y,vmax=1e3,log=True, cmp =cmocean.cm.thermal ): 
    #print((vol_xy.head(5)))
    da_vol_xy = vol_xy.to_xarray()[y]
    #print(da_vol_xy.head(4))
    # Define coordinates x_c and y_c which are the Pythonic indices rather than the TRACMASS indices. This ensures agreement with the coordinates for ds_domain
  
    da_vol_xy = da_vol_xy.assign_coords( {'x_c':da_vol_xy.binnedx_o-1 , 'y_c':da_vol_xy.binnedy_o - 1} ) 
    da_vol_xy = da_vol_xy.swap_dims({'binnedx_o':'x_c', 'binnedy_o':'y_c'})
    
    # Reorder axes to agree with ds_subdomain
    da_vol_xy = da_vol_xy.transpose("y_c","x_c",...)
    
    
    # Align the coordinates of the grid file with the subdomain in da_vol_xy
    ds_domain_allign, da_vol_xy = xr.align( ds_domain, da_vol_xy )

    fig, ax = plt.subplots(1,1,dpi=200,subplot_kw={'projection':ccrs.SouthPolarStereo()})
    lat = ds_domain_allign.gphit
    lon = ds_domain_allign.glamt
    
    
    
    #vmax = vnorm.max().compute()

    
    vmin=vmax*1e-3    
    if log == True:
        lognorm = matplotlib.colors.LogNorm(vmax = vmax, vmin = vmax /1e3 )
        cax = ax.pcolormesh( lon, lat, da_vol_xy, transform=ccrs.PlateCarree(), cmap=cmp, norm=lognorm )
    else:
        cax = ax.pcolormesh( lon, lat,  da_vol_xy, transform=ccrs.PlateCarree(), cmap=cmp)
    ax.coastlines()
    fig.colorbar(cax)
    return fig ,ax

# %%
def plot_i(ds_domain, vol_xy, y,vmax=1e3,vmin=1,log=True, cmp =cmocean.cm.thermal ): 
    #print((vol_xy.head(5)))
    da_vol_xy = vol_xy.to_xarray()[y]
    #print(da_vol_xy.head(4))
    # Define coordinates x_c and y_c which are the Pythonic indices rather than the TRACMASS indices. This ensures agreement with the coordinates for ds_domain
  
    da_vol_xy = da_vol_xy.assign_coords( {'x_c':da_vol_xy.binnedx_i-1 , 'y_c':da_vol_xy.binnedy_i - 1} ) 
    da_vol_xy = da_vol_xy.swap_dims({'binnedx_i':'x_c', 'binnedy_i':'y_c'})
    
    # Reorder axes to agree with ds_subdomain
    da_vol_xy = da_vol_xy.transpose("y_c","x_c",...)
    
    
    # Align the coordinates of the grid file with the subdomain in da_vol_xy
    ds_domain_allign, da_vol_xy = xr.align( ds_domain, da_vol_xy )

    fig, ax = plt.subplots(1,1,dpi=200,subplot_kw={'projection':ccrs.SouthPolarStereo()})
    lat = ds_domain_allign.gphit
    lon = ds_domain_allign.glamt
    
    
    
    #vmax = vnorm.max().compute()

    
       
    if log == True:
        vmin=vmax*1e-3 
        lognorm = matplotlib.colors.LogNorm(vmax = vmax, vmin = vmax /1e3 )
        cax = ax.pcolormesh( lon, lat, da_vol_xy, transform=ccrs.PlateCarree(), cmap=cmp, norm=lognorm )
    else:
        norm = Normalize(vmin=vmin, vmax=vmax)
        cax = ax.pcolormesh( lon, lat,  da_vol_xy, transform=ccrs.PlateCarree(),norm=norm, cmap=cmp)
    ax.coastlines()
    fig.colorbar(cax)
    return fig ,ax

# %%
def plot_depth_subvol(d_min,d_max,ax,xmin,xmax,df): # plot seeding depth & volume in density class, integrated around longitudes
    cmp =cmocean.cm.thermal 
    df_densest = df[(df['ndense']<d_max) &(df['ndense']>d_min) ][['bin_depth_i','binnedy_i','subvol_i','year_o','binnedx_i']]
    df_densest= df_densest[df_densest['year_o']>1983]
    df_densest = df_densest[(df_densest['binnedx_i']>xmin )&(df_densest['binnedx_i']<xmax)] 
    df_group = df_densest.groupby(['binnedy_i','bin_depth_i'])
    count = df_group.sum('subvol_i').compute()
    count = count.reset_index()
    print(max(count.binnedy_i.values))
    count['lats'] = (ds_domain.e2t.gphit[:398,0])[count.binnedy_i.values-1]
# Pivot the DataFrame to get a 2D grid
    grid = count.pivot(index="bin_depth_i", columns="lats", values="subvol_i")
    #print(grid)
    # Extract the X, Y meshgrid from index and columns
    #print(max(count.binnedy_i))
    yy, zz = np.meshgrid(grid.columns, grid.index)
    
    # Extract the Z values (subvol_i) ensuring correct shape
    Z = grid.values
    
    ### now normalise by area of box
    xvals = ds_domain.e1t.values[:,0][:398]
    yvals = ds_domain.e2t.values[:,0][:398]
    zvals = ds_domain.e3t_1d.values
    zy_matrix = da.outer(zvals, yvals)  # Shape: (len(zvals), 398)


    vol = (zy_matrix * xvals)
   
    
    #print(da.shape(vol))
    shp = da.shape(Z)
    #print(shp)
    vol = vol[:shp[0],:shp[1]]
    cax = ax.pcolormesh(yy, zz, Z/vol, cmap=cmp)


    #now add max depth bathymetry
    bathy = ds_domain.mbathy.values[:398,xmin:xmax]
    #print(da.shape(bathy))
    real_depths = ds_domain.e3t_1d['gdept_1d']
    max_bathy = np.max(bathy, axis = 1)
    bathy_depths = real_depths[max_bathy]
    #print(len(bathy_depths))
    #print(1442,398)
    ax.plot(ds_domain.e2t.gphit[:398,0],bathy_depths, c = 'black',lw = 2)
    cbar=fig.colorbar(cax)
    cbar.set_label(r"Normalised Volume ($m^3$/$m^3$)", fontsize=14)
    #print(bathy_depths)
    for i,surf in enumerate([surf1,surf2]):
        zonal_avg = da.nanmean(surf.ns_depth.values[0][0][:,xmin:xmax], axis =1)
        plt.plot(ds_domain.e2t.gphit[:398,0],zonal_avg,c = col[i],lw = 1)
    #plt.colorbar(cax, ax=ax, label="Subvol_i")

# %%
def plot_depth_var(d_min,d_max,ax,xmin,xmax,df,var): # plot seeding depth & volume in density class, integrated around longitudes
    cmp =cmocean.cm.thermal 
    df_densest = df[(df['ndense']<d_max) &(df['ndense']>d_min) ][['bin_depth_i','binnedy_i','subvol_i','year_o','binnedx_i','time_o',var]]
    df_densest= df_densest[df_densest['time_o']>1983]
    df_densest = df_densest[(df_densest['binnedx_i']>xmin )&(df_densest['binnedx_i']<xmax)] 
    df_group = df_densest.groupby(['binnedy_i','bin_depth_i'])
    count = df_group.mean(var).compute()
    count = count.reset_index()
    print(max(count.binnedy_i.values))
    count['lats'] = (ds_domain.e2t.gphit[:398,0])[count.binnedy_i.values-1]
# Pivot the DataFrame to get a 2D grid
    grid = count.pivot(index="bin_depth_i", columns="lats", values=var)
    #print(grid)
    # Extract the X, Y meshgrid from index and columns
    #print(max(count.binnedy_i))
    yy, zz = np.meshgrid(grid.columns, grid.index)
    
    # Extract the Z values (subvol_i) ensuring correct shape
    Z = grid.values
    
   


   
    
    #print(da.shape(vol))
 
    #print(shp)
    
    cax = ax.pcolormesh(yy, zz, Z, cmap=cmp)


    #now add max depth bathymetry
    bathy = ds_domain.mbathy.values[:398,xmin:xmax]
    #print(da.shape(bathy))
    real_depths = ds_domain.e3t_1d['gdept_1d']
    max_bathy = np.max(bathy, axis = 1)
    bathy_depths = real_depths[max_bathy]
    #print(len(bathy_depths))
    #print(1442,398)
    ax.plot(ds_domain.e2t.gphit[:398,0],bathy_depths, c = 'black',lw = 2)
    cbar=fig.colorbar(cax)
    cbar.set_label(f"{var}  (s)", fontsize=14)
    '''
    for i,surf in enumerate([surf1,surf2]):
        zonal_avg = da.nanmean(surf.ns_depth.values[0][0][:,xmin:xmax], axis =1)
        plt.plot(ds_domain.e2t.gphit[:398,0],zonal_avg,c = col[i],lw = 1)
    #print(bathy_depths)
    
    #plt.colorbar(cax, ax=ax, label="Subvol_i")
    '''

# %%
surf.ns_depth.values[0][0]
# Out:
# array([[          nan,           nan,           nan, ...,           nan,
#                   nan,           nan],
#        [          nan,           nan,           nan, ...,           nan,
#                   nan,           nan],
#        [          nan,           nan,           nan, ...,           nan,
#                   nan,           nan],
#        ...,
#        [2798.11781475, 2794.39855204, 2819.11988043, ..., 2789.71840308,
#         2795.19348261, 2812.46109854],
#        [2811.75512602, 2783.41186804, 2804.7313653 , ..., 2767.14154716,
#         2788.77855457, 2807.50715952],
#        [2813.20655323, 2787.09892759, 2811.77582132, ..., 2761.09501429,
#         2779.26303133, 2798.70444342]], shape=(398, 1440))

# %%
df_gyre = df_vent[(df_vent['sf_zint']<200) & (df_vent['sf_zint']>10)]
df_weddel_gyre = df_gyre[(df_gyre['binnedx_i']>930)]

# %%
df_gyre_int = df_weddel_gyre[['binnedx_i','binnedy_i','subvol_i']]
df_group = df_gyre_int.groupby(['binnedx_i','binnedy_i'])
count = df_group.sum('subvol_i').compute()
plot_i(ds_domain,count,'subvol_i',vmax=1e12,log=False)
# Out:
# (<Figure size 1280x960 with 2 Axes>, <GeoAxes: >)

# %%
df_gyre_int = df_weddel_gyre[['binnedx_o','binnedy_o','subvol_o']]
df_group = df_gyre_int.groupby(['binnedx_o','binnedy_o'])
count = df_group.sum('subvol_o').compute()
plot_o(ds_domain,count,'subvol_o',vmax=1e12)
# Out:
# (<Figure size 1280x960 with 2 Axes>, <GeoAxes: >)

# %%
###merge df_gyre onto df_vent hence adding 1s& nan

# %%
df_gyre_copy = df_weddel_gyre.copy()[['binnedx_i','binnedy_i']]
df_gyre_copy = df_gyre_copy.assign(vent_bool=1) # 0 ventilates not in gyre, 1 ventilates in gyre
df_gyre_copy=df_gyre_copy.rename(columns={"binnedx_i": "binnedx_o", "binnedy_i": "binnedy_o"})

# %%
df_gyre_copy
# Out:
# Dask DataFrame Structure:
#                 binnedx_o binnedy_o vent_bool
# npartitions=236
#                     int64     int64     int64
#                       ...       ...       ...
# ...                   ...       ...       ...
#                       ...       ...       ...
#                       ...       ...       ...
# Dask Name: operation, 12 expressions
# Expr=RenameFrame(frame=Assign(frame=(Filter(frame=Filter(frame=ReadParquetFSSpec(7456362), predicate=ReadParquetFSSpec(7456362)['sf_zint'] < 200 & ReadParquetFSSpec(7456362)['sf_zint'] > 10), predicate=(Filter(frame=ReadParquetFSSpec(7456362), predicate=ReadParquetFSSpec(7456362)['sf_zint'] < 200 & ReadParquetFSSpec(7456362)['sf_zint'] > 10))['binnedx_i'] > 930))[['binnedx_i', 'binnedy_i']]), columns={'binnedx_i': 'binnedx_o', 'binnedy_i': 'binnedy_o'})

# %%
df_merge = df_vent[['binnedx_i','binnedy_i','subvol_i','binnedx_o','binnedy_o','subvol_o','density_o']].merge(df_gyre_copy,on = ['binnedx_o','binnedy_o'])

# %%
df_vent.dtypes
# Out:
# ntraj_o            int64
# x_o              float64
# y_o              float64
# z_o              float64
# subvol_o         float64
# time_o           float64
# boxface_o          int64
# temp_o           float64
# sal_o            float64
# density_o        float64
# density10_o      float64
# ntrajc             int64
# ntraj_i            int64
# x_i              float64
# y_i              float64
# z_i              float64
# subvol_i         float64
# time_i           float64
# boxface_i          int64
# temp_i           float64
# sal_i            float64
# density_i        float64
# density10_i      float64
# year_i             int64
# month_i            int64
# day_i              int64
# dayofyear_i        int64
# year_o             int64
# month_o            int64
# day_o              int64
# dayofyear_o        int64
# binnedx_i          int64
# binnedy_i          int64
# binnedz_i          int64
# binnedx_o          int64
# binnedy_o          int64
# binnedz_o          int64
# ...

# %%
### look at those that ventilate in the weddel gyre
df_vent_in_gyre = df_vent[df_vent['weddel_bool']==1]
df_vent_in_gyre = df_vent_in_gyre[df_vent_in_gyre['ndense']>1000]

# %%
df_vent_in_gyre.head(5)
# Out:
#    ntraj_o      x_o     y_o    z_o      subvol_o       time_o  boxface_o  \
# 2    66053  1127.10  183.04  22.40  9.814359e+08  804388320.0          0
# 3   753712  1150.56  249.04  23.97  9.844779e+08  457492320.0          0
# 4   597289  1072.14  227.87  14.18  5.566691e+08    1270080.0          0
# 5   599368  1133.57  214.63  19.31  8.383696e+08    9076320.0          0
# 6    12675  1068.09  183.68  22.26  8.657654e+08   17716320.0          0
#
#    temp_o  sal_o  density_o  ...  nd_bin_ini    sf_zint  bathy_depth_i  \
# 2   -1.51  34.20      27.39  ...         113  33.535847    4939.152344
# 3    0.36  33.72      26.92  ...          80 -85.403865    4129.458008
# 4    0.59  33.44      26.69  ...          73  20.780512    4475.523438
# 5    0.89  33.87      27.02  ...          79  42.896949    3883.778076
# 6   -1.10  34.25      27.42  ...          92  43.595940    4787.701993
#
#    bathy_depth_o       ndense  bin_depth_o     depth_o  bin_depth_i  \
# ...

# %%
'''
#init position
df_gyre_int = df_vent_in_gyre[['binnedx_i','binnedy_i','subvol_i']]
df_group = df_gyre_int.groupby(['binnedx_i','binnedy_i'])
count = df_group.sum(['subvol_i']).compute()
plot_i(ds_domain,count,'subvol_i',vmax=1e14)
plt.savefig('../fig/log_initial_pos_traj_vent_in_gyre.png')
print('plot origin of traj')


###check origpos
df_gyre_int = df_vent_in_gyre[['binnedx_o','binnedy_o','subvol_o']]
df_group = df_gyre_int.groupby(['binnedx_o','binnedy_o'])
count = df_group.sum('subvol_o').compute()
plot_o(ds_domain,count,'subvol_o',vmax=1e14)
plt.savefig('../fig/check_gyre_pos.png')
print('plot gyre pos')
'''

'''
#look at densities
df_gyre_int = df_vent_in_gyre[['binnedx_i','binnedy_i','ndense']]
df_gyre_int = df_gyre_int[ df_gyre_int['ndense']>1000]
df_group = df_gyre_int.groupby(['binnedx_i','binnedy_i'])
count = df_group.mean(['ndense']).compute()
plot_i(ds_domain,count,'ndense',log=False,vmin=1026.5,vmax=1027.7)
plt.savefig('../fig/init_dens_vent_in_gyre.png')
print('densities')
'''

#Density at point of ventilation (plotted at starting pos)
'''
df_gyre_int = df_vent_in_gyre[['binnedx_i','binnedy_i','density_o']]
df_gyre_int = df_gyre_int[ df_gyre_int['density_o']>20]

df_group = df_gyre_int.groupby(['binnedx_i','binnedy_i'])
count = df_group.mean(['density_o']).compute()
plot_i(ds_domain,count,'density_o',log=False)
plt.savefig('../fig/vent_dens_trsjfromxy.png')
print('densities')
'''

#######
'''
df = df_vent_in_gyre[['ndense','density_o']]
df=df[df['ndense']>1000]
df_group= df.groupby('ndense')
dens = df_group.mean('density_o').compute()

dens = dens.reset_index()
dens=dens.sort_values('ndense')

fig,ax = plt.subplots(1,1)
plt.plot(dens['ndense'],1000+dens['density_o'],c='red')
plt.plot([1026.3,1027.7],[1026.3,1027.7],ls='--')
plt.xlabel('neut density')
plt.ylabel('density out')

ax.xaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))

# Get current ticks and remove every second one
xticks = ax.get_xticks()
ax.set_xticks(xticks[::2])  # Keep every second tick
plt.savefig('../fig/gyres_ventilated.png')
'''

# %%
df_vent.dtypes
# Out:
# ntraj_o            int64
# x_o              float64
# y_o              float64
# z_o              float64
# subvol_o         float64
# time_o           float64
# boxface_o          int64
# temp_o           float64
# sal_o            float64
# density_o        float64
# density10_o      float64
# ntrajc             int64
# ntraj_i            int64
# x_i              float64
# y_i              float64
# z_i              float64
# subvol_i         float64
# time_i           float64
# boxface_i          int64
# temp_i           float64
# sal_i            float64
# density_i        float64
# density10_i      float64
# year_i             int64
# month_i            int64
# day_i              int64
# dayofyear_i        int64
# year_o             int64
# month_o            int64
# day_o              int64
# dayofyear_o        int64
# binnedx_i          int64
# binnedy_i          int64
# binnedz_i          int64
# binnedx_o          int64
# binnedy_o          int64
# binnedz_o          int64
# ...

# %%
#init position

df_gyre_int = df_vent_in_gyre[['binnedx_i','binnedy_i','subvol_i']]
xmin,xmax = 0,1442
df_gyre_int = df_gyre_int[(df_gyre_int['binnedx_i']>xmin )&(df_gyre_int['binnedx_i']<xmax)] 

df_group = df_gyre_int.groupby(['binnedx_i','binnedy_i'])
count = df_group.sum(['subvol_i']).compute()
plot_i(ds_domain,count,'subvol_i',vmax=1e12)
plt.savefig('../fig/log_initial_pos_traj_vent_in_gyre.png')
print('plot origin of traj')
# Out:
# plot origin of traj

# %%
len(df_vent)
# Out:
# 54157552

# %%
df_vent.dtypes
# Out:
# ntraj_o            int64
# x_o              float64
# y_o              float64
# z_o              float64
# subvol_o         float64
# time_o           float64
# boxface_o          int64
# temp_o           float64
# sal_o            float64
# density_o        float64
# density10_o      float64
# ntrajc             int64
# ntraj_i            int64
# x_i              float64
# y_i              float64
# z_i              float64
# subvol_i         float64
# time_i           float64
# boxface_i          int64
# temp_i           float64
# sal_i            float64
# density_i        float64
# density10_i      float64
# year_i             int64
# month_i            int64
# day_i              int64
# dayofyear_i        int64
# year_o             int64
# month_o            int64
# day_o              int64
# dayofyear_o        int64
# binnedx_i          int64
# binnedy_i          int64
# binnedz_i          int64
# binnedx_o          int64
# binnedy_o          int64
# binnedz_o          int64
# ...

# %%
#age of vent at init position
df_gyre_int = df_vent_in_gyre[['binnedx_i','binnedy_i','subvol_i','year_o','time_o']]
df_gyre_int=df_gyre_int[df_gyre_int['year_o']>1983]
df_group = df_gyre_int.groupby(['binnedx_i','binnedy_i'])
count = df_group.mean(['time_o']).compute()
plot_i(ds_domain,count,'time_o',log = False)
#plt.savefig('../fig/log_initial_pos_traj_vent_in_gyre.png')
print('plot origin of traj')
# Out:
# plot origin of traj

# %%
df_vent_in_gyre['delta'] = -(df_vent_in_gyre['ndense']-df_vent_in_gyre['density_o']-1000)

# %%
plt.hist(df_vent_in_gyre['delta'].compute(),bins=200)
plt.show()

# %%
df_vent['delta'] = df_vent['ndense']-df_vent['density_o']-1000

# %%
#### density change

df_gyre_int = df_vent_in_gyre[['binnedx_i','binnedy_i','year_o','delta']]
#df_gyre_int=df_gyre_int[df_gyre_int['binnedy_i']<200]
df_gyre_int=df_gyre_int[df_gyre_int['year_o']>1983]
df_group = df_gyre_int.groupby(['binnedx_i','binnedy_i'])
count = df_group.mean(['delta']).compute()
plot_i(ds_domain,count,'delta',log = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 #### density change
# ----> 3 df_gyre_int = df_vent_in_gyre[['binnedx_i','binnedy_i','year_o','delta']]
#       4 #df_gyre_int=df_gyre_int[df_gyre_int['binnedy_i']<200]
#       5 df_gyre_int=df_gyre_int[df_gyre_int['year_o']>1983]
#
# NameError: name 'df_vent_in_gyre' is not defined

# %%
surf1= xr.open_dataset('/gws/nopw/j04/bas_pog/astyles/SouthernDemons/neutraldensity/output/ORCA025_Dec1982/ns_Dec_depth2491_ipin950_jpin_275_itermax10.nc')
surf2= xr.open_dataset('/gws/nopw/j04/bas_pog/astyles/SouthernDemons/neutraldensity/output/ORCA025_Dec1982/ns_Dec_depth1914_ipin950_jpin_275_itermax10.nc')

# %%
print(surf1.sigma_ver.values)
surf2.sigma_ver.values
# Out:
# [1027.70891887]
# array([1027.65051265])

# %%
# look at depth distribution of ASC?
fig,ax = plt.subplots(1,1,figsize = (15,5))
plot_depth_subvol(1000,1030,ax,250,550,df_vent_in_gyre)
ax.invert_yaxis()
plt.show()
# Out:
# 398

# %%
for xmin in np.linspace(50,650,13):
    xmin = int(xmin)
    fig,ax = plt.subplots(1,1,figsize = (15,5))
    plot_depth_subvol(1000,1030,ax,xmin,xmin+50,df_vent_in_gyre)
    ax.invert_yaxis()
    plt.show()
# Out:
# 394
# 396
# 387
# 354
# 341
# 398
# 398
# 398
# 397
# 393
# 389
# 396
# 388

# %%
#look at avg deltas
for xmin in np.linspace(50,650,7):
    xmin = int(xmin)
    fig,ax = plt.subplots(1,1,figsize = (15,5))
    plot_depth_var(1000,1030,ax,xmin,xmin+100,df_vent_in_gyre,'delta')
    ax.invert_yaxis()
    plt.show()
# Out:
# 396
# 387
# 398
# 398
# 397
# 396
# 388

# %%
(0|0)
# Out:
# 0

# %%
# separate out the trajectories that move into the gyre

# %%
start = df_vent[(df_vent['sf_zint']<200) | (df_vent['sf_zint']<10)]
start= start[start['binnedx_i']<930]
#start = start.dropna(subset=['weddel_bool'])

move = start[(start['weddel_bool']==1)]

# %%
move.head()
# Out:
#      ntraj_o      x_o     y_o    z_o      subvol_o        time_o  boxface_o  \
# 85    389625  1083.99  225.43  23.75  9.650792e+08  5.874638e+08          0
# 86    318508  1341.15  160.14  20.75  9.573288e+08  3.265963e+08          0
# 91    102302   953.96  218.91  13.00  8.244611e+08  4.337813e+06          6
# 146   604977  1315.30  205.28  22.17  9.792399e+08  5.179723e+08          0
# 152   599729  1189.42  242.99  23.52  9.547701e+08  3.655584e+08          0
#
#      temp_o  sal_o  density_o  ...  nd_bin_ini    sf_zint  bathy_depth_i  \
# 85    -0.67  33.79      27.03  ...          96  -8.607716    4156.073242
# 86    -0.48  33.95      27.16  ...          84 -41.864967    4356.776367
# 91     3.86  33.74      26.68  ...          73 -16.219840    3801.072115
# 146    0.19  33.82      27.02  ...          86 -65.874969    3418.722975
# 152   -0.85  34.03      27.23  ...          95   7.921147    3559.193115
#
# ...

# %%
move = move[move['year_o']>1983]
move = move[move['binnedy_i']<250]
df_gyre_int = move[['binnedx_i','binnedy_i','subvol_i']]
xmin,xmax = 0,1442
df_gyre_int = df_gyre_int[(df_gyre_int['binnedx_i']>xmin )&(df_gyre_int['binnedx_i']<xmax)] 

df_group = df_gyre_int.groupby(['binnedx_i','binnedy_i'])
count = df_group.sum(['subvol_i']).compute()
plot_i(ds_domain,count,'subvol_i',log = False)
#plt.savefig('../fig/log_initial_pos_traj_vent_in_gyre.png')
print('plot origin of traj')
# Out:
# plot origin of traj

# %%
move = move[move['year_o']>1983]
move = move[move['binnedy_i']<250]
move = move[move['delta']>-10]
df_gyre_int = move[['binnedx_i','binnedy_i','subvol_i','time_o']]
xmin,xmax = 0,1442
df_gyre_int = df_gyre_int[(df_gyre_int['binnedx_i']>xmin )&(df_gyre_int['binnedx_i']<xmax)] 

df_group = df_gyre_int.groupby(['binnedx_i','binnedy_i'])
count = df_group.mean(['time_o']).compute()
plot_i(ds_domain,count,'time_o',log=False,vmin=1e8,vmax=1e9)
#plt.savefig('../fig/log_initial_pos_traj_vent_in_gyre.png')
print('plot origin of traj')
# Out:
# plot origin of traj

# %%
start = df_vent[(df_vent['sf_zint']<200) | (df_vent['sf_zint']<10)]
start= start[start['binnedx_i']<930]
#start = start.dropna(subset=['weddel_bool'])

move = start[(start['weddel_bool']==1)]
df_gyre_int = move[['binnedx_o','binnedy_o','subvol_o','time_o']]
xmin,xmax = 0,1442
df_gyre_int = df_gyre_int[(df_gyre_int['binnedx_o']>xmin )&(df_gyre_int['binnedx_o']<xmax)] 

df_group = df_gyre_int.groupby(['binnedx_o','binnedy_o'])
count = df_group.sum(['subvol_o']).compute()

# %%
plot_o(ds_domain,count,'subvol_o',vmax = 1e11)

# %%
###### look at whole dataset again
df_vent_int = df_vent[df_vent['year_o']>1983]

# %%
for xmin in np.linspace(0,1400,15):
    xmin = int(xmin)
    fig,ax = plt.subplots(1,1,figsize = (15,5))
    plot_depth_subvol(1000,1030,ax,xmin,xmin+100,df_vent_int)
    ax.invert_yaxis()
    plt.show()
# Out:
# 398
# 398
# 357
# 398
# 398
# 398
# 398
# 398
# 398
# 398
# 398
# 398
# 398
# 398
# 398

# %%
for xmin in np.linspace(0,1400,15):
    xmin = int(xmin)
    fig,ax = plt.subplots(1,1,figsize = (15,5))
    plot_depth_var(1000,1030,ax,xmin,xmin+100,df_vent_int,'delta')
    ax.invert_yaxis()
    plt.show()
# Out:
# 398
# 398
# 357
# 398
# 398
# 398
# 398
# 398
# 398
# 398
# 398
# 398
# 398
# 398
# 398
